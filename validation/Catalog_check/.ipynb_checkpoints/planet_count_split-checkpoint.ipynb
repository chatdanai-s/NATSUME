# %% [markdown]
# ## Splits data into ones with 1 planet and 2 planets respectively.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Import cleaned/merged dataset
FILENAME = r'data_cleaned\merged_GLSfitted.csv'
df = pd.read_csv(FILENAME)
# Drop unused columns
df = df.drop(columns=['pl_letter', 'mass_sini', 'mass_sini_error', 'radius', 'radius_error'])

df.head(3)
# Out:
#   name_exoclock name_exoplanet.eu star_name  T0_(BJD_TDB)  T0_unc.  P_(days)  \
# 0           NaN         55 Cnc Ab  55 Cnc A           NaN      NaN       NaN
# 1           NaN         55 Cnc Ac  55 Cnc A           NaN      NaN       NaN
# 2           NaN         55 Cnc Ad  55 Cnc A           NaN      NaN       NaN
#
#    P_unc.    mass  mass_error  orbital_period  ...  Attv2  Nbest  scatter  \
# 0     NaN  0.8400      0.2300        14.65314  ...    NaN    NaN      NaN
# 1     NaN  0.1714      0.0055        44.37300  ...    NaN    NaN      NaN
# 2     NaN  3.8780      0.0680      5574.20000  ...    NaN    NaN      NaN
#
#    bic0  bic1  bic2  delta_bic  fap  sampled_f  TTV_strength
# 0   NaN   NaN   NaN        NaN  NaN        NaN           NaN
# 1   NaN   NaN   NaN        NaN  NaN        NaN           NaN
# 2   NaN   NaN   NaN        NaN  NaN        NaN           NaN
#
# [3 rows x 36 columns]

# %%
# Mask by planet_count = 1
df_1p = df[df.planet_count == 1]
df_1p = df_1p.drop(columns=['orbital_period', 'orbital_period_error'])
EXPORT_FILENAME = r'data_cleaned\merged_1planet.csv'
df_1p.to_csv(EXPORT_FILENAME, index=False)
df_1p.head(3)
# Out:
#   name_exoclock name_exoplanet.eu star_name  T0_(BJD_TDB)   T0_unc.  P_(days)  \
# 5      CoRoT-1b         CoRoT-1 b   CoRoT-1  2.455112e+06  0.000067  1.508968
# 6     CoRoT-11b        CoRoT-11 b  CoRoT-11  2.456068e+06  0.000340  2.994278
# 7     CoRoT-19b        CoRoT-19 b  CoRoT-19  2.456551e+06  0.000450  3.897138
#
#          P_unc.  mass  mass_error  eccentricity  ...     Attv2  Nbest  \
# 5  5.800000e-08  1.03        0.12         0.071  ...  0.001136    2.0
# 6  4.500000e-07  2.33        0.27         0.072  ...  0.002477    2.0
# 7  8.800000e-07  1.11        0.06         0.047  ...       NaN    1.0
#
#     scatter         bic0         bic1         bic2  delta_bic  fap  sampled_f  \
# 5  0.558962 -1054.658397 -1052.437831 -1054.619929  -0.038468  NaN    19395.0
# 6  0.565121  -324.102760  -327.046854  -336.983841  12.881082  NaN     9174.0
# 7  0.370604  -223.703462  -227.203312  -217.081188   3.499851  1.0     6455.0
#
#    TTV_strength
# 5        no_TTV
# 6        no_TTV
# 7        no_TTV
#
# [3 rows x 34 columns]

# %%
df_2p = df[df.planet_count == 2]

# Sort by ascending star_name, descending period
df_2p = df_2p.sort_values(by=['star_name', 'orbital_period'], ascending=[True, False])
# Assumes exactly 2 rows per star_name. Higher period → outer, lower → inner.
df_2p['planet_pos'] = (
    df_2p.groupby('star_name')
      .cumcount()
      .map({0: 'outer', 1: 'inner'})
)

# Get period ratio P2/P1
df_2p['period_ratio'] = (
    df_2p.pivot(index='star_name', columns='planet_pos', values='orbital_period')
      .eval('outer / inner')
      .reindex(df_2p['star_name'])
      .to_numpy()
)

# Find approximate MMR
allowed_MMR = {
    '2:1': 2/1, '3:2': 3/2, '4:3': 4/3, '5:4': 5/4,
    '3:1': 3/1, '5:3': 5/3, '7:5': 7/5,
    '4:1': 4/1, '5:2': 5/2,
    '5:1': 5/1, '7:3': 7/3}
vals = np.array(list(allowed_MMR.values()))
keys = np.array(list(allowed_MMR.keys()))

def closest_allowed_MMR(x):
    if np.isnan(x) or x >= 4.1:
        return np.nan
    return keys[np.argmin(np.abs(vals - x))]

df_2p['MMR'] = df_2p['period_ratio'].apply(closest_allowed_MMR)

# Get j and N
from natsume.common import get_MMR
df_2p[['j', 'N']] = (
    df_2p['MMR']
      .apply(lambda x: pd.Series(get_MMR(x)) if isinstance(x, str) else pd.Series([np.nan, np.nan]))
)
# Get Delta
from natsume.common import get_NormalizedResonanceDistance
df_2p['Delta'] = get_NormalizedResonanceDistance(1, df_2p.period_ratio, df_2p.j, df_2p.N)

EXPORT_FILENAME = r'data_cleaned\merged_2planet.csv'
df_2p.to_csv(EXPORT_FILENAME, index=False)
df_2p.head(3)
# Out:
#    name_exoclock name_exoplanet.eu star_name  T0_(BJD_TDB)   T0_unc.  \
# 13           NaN         GJ 1132 c   GJ 1132           NaN       NaN
# 12       GJ1132b         GJ 1132 b   GJ 1132  2.458041e+06  0.000093
# 32           NaN        HAT-P-11 c  HAT-P-11           NaN       NaN
#
#     P_(days)        P_unc.      mass  mass_error  orbital_period  ...  \
# 13       NaN           NaN  0.008316    0.001381        8.929000  ...
# 12   1.62893  8.600000e-07  0.005220    0.000720        1.628931  ...
# 32       NaN           NaN  3.060000    0.400000     3299.000000  ...
#
#     delta_bic       fap  sampled_f  TTV_strength  planet_pos  period_ratio  \
# 13        NaN       NaN        NaN           NaN       outer      5.481509
# 12  -7.567203  0.000001     8764.0        no_TTV       inner      5.481509
# 32        NaN       NaN        NaN           NaN       outer    674.945446
#
#     MMR   j   N  Delta
# 13  NaN NaN NaN    NaN
# 12  NaN NaN NaN    NaN
# 32  NaN NaN NaN    NaN
#
# [3 rows x 42 columns]
